# %% [markdown]
# # Initialization

# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt
import params_searchers.feature_importance_extractor as feat_imp_ext
import lgbm_optuna_column_filter as lgbm_fl
import pandas as pd
from sklearn.model_selection import TimeSeriesSplit
import params_searchers.ts_splitter as ts_splitter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Constants

# %%
METRIC = 'rmse'
OBJECTIVE = 'regression'
OPTIMIZATION_DIRECTION = 'minimize'
CATEGORIES = [[], ['season'], ['month'], ['year'], ['season', 'month'], ['season', 'month', 'year'], ['season', 'month', 'weekday']]

TRAIN_DATE_FROM = '2015-01-08'
TRAIN_DATE_TO = '2023-02-05'
VAL_DATE_FROM = '2023-02-06'
VAL_DATE_TO = '2023-02-12'

CSV_JOINT_FILE = '../../datasources/ds_joint/ds.csv'
CSV_SCORE_FILE = '../../datasources/pm25_scores/score.csv'

# %% [markdown]
# ## Source data load

# %%
df_joint = pd.read_csv(CSV_JOINT_FILE, parse_dates=True, index_col='DatetimeEnd')

# %%
df_score = pd.DataFrame(columns=['train_score', 'val_score', 'target', 'pol_id', 'weather_YN', 'AQI_lags_YN', 'C_lags_YN', 'simple_lags_YN', 'gen_lags_YN', 'params', 'categories', 'top_feat_count'])

# %% [markdown]
# ## Functions

# %%
def score_by_feature_count(o_helper, len_features, best_params, categories):
    tr_by_cat = []
    vl_by_cat = []
    o_helper.study_best_params = best_params
    for cat in categories:
        train_scs = []
        val_scs = []
        for i in range(1, len_features):
            o_helper.set_best_features_by_count(i)
            score_tr, score_vl, mdl = o_helper.run_model_and_eval(params=best_params,  categorical_features=cat, best_features_only=True, set_as_best_model=False)
            train_scs.append(score_tr)
            val_scs.append(score_vl)
        tr_by_cat.append(train_scs)
        vl_by_cat.append(val_scs)
    return tr_by_cat, vl_by_cat


def plot_score_grouped_by_categories_by_feature_count(len_features, score_by_cat, sub_title=""):
    plt.figure(figsize=(21, 7))
    for i in range(0, len(categories)):
        plt.plot(range(1, len_features),score_by_cat[i], label=("_".join(categories[i]) if len(categories[i]) > 0 else "no_cat"))
    plt.title(f'Score by features count. {sub_title}')
    plt.legend()
    plt.show()


def plot_train_val_score_by_feature_count(len_features, train_scs, val_scs, sub_title=""):
    plt.figure(figsize=(21, 7))
    plt.plot(range(1, len_features),train_scs, label="train_score")
    plt.plot(range(1, len_features),val_scs, label="val_score")
    plt.title(f'Train/Val score by features count. {sub_title}')
    plt.legend()
    plt.show()


def score_and_plot_by_feature_count(o_helper, len_features, best_params, categories):
    tr_by_cat, vl_by_cat = score_by_feature_count(o_helper, len_features, best_params, categories)
    plot_score_grouped_by_categories_by_feature_count(len_features, tr_by_cat, sub_title="Train scores")
    plot_score_grouped_by_categories_by_feature_count(len_features, vl_by_cat, sub_title="Val scores")
    for i in range(len(categories)):
        plot_train_val_score_by_feature_count(len_features, tr_by_cat[i], vl_by_cat[i],
                                              sub_title=f"First cats: {('_'.join(categories[i]) if len(categories[i]) > 0 else 'no_cat')}")


def init_optuna_helper(df, pol_id, default_category, categories, use_aqi_cols=False, use_c_mean_cols=True, use_lag_cols=True, use_gen_lags_cols=True, use_weather_cols=True):
    default_params = {'n_jobs': -1, 'verbosity': -1, 'metric': METRIC, 'boosting_type': 'gbdt',
    'extra_trees': True, 'n_estimators': 1000, 'num_leaves': 150, 'learning_rate': 0.01, 'subsample': 0.7, 'subsample_freq': 5, 'subsample_for_bin': 100000, 'min_child_samples': 30, 'reg_alpha': 0.1, 'reg_lambda': 0.2, 'max_depth': 10, 'max_bin': 150}
    o_helper, x_tr, y_tr, x_vl, y_vl = lgbm_fl.init_optuna(
        df=df, pol_id=pol_id, prediction_value_type=lgbm_fl.PredictionValueType.AQI,
        use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols,
        train_start_dt=TRAIN_DATE_FROM, train_end_dt=TRAIN_DATE_TO, test_start_dt=VAL_DATE_FROM, test_end_dt=VAL_DATE_TO, default_params=default_params, default_category=default_category, categories_for_optimization=categories, default_top_features_count=-1)
    return o_helper, x_tr, y_tr, x_vl, y_vl


def run_test(df, pol_id, default_category, categories, use_aqi_cols=False, use_c_mean_cols=True, use_lag_cols=True, use_gen_lags_cols=True, use_weather_cols=True):

    o_helper, x_tr, y_tr, x_vl, y_vl = init_optuna_helper(df, pol_id, default_category, categories, use_aqi_cols, use_c_mean_cols, use_lag_cols,use_gen_lags_cols, use_weather_cols)

    o_helper.run_params_search(n_trials=100, n_jobs=6, study_name="_", save_best_params=True,   direction=OPTIMIZATION_DIRECTION, best_features_only=True, search_category=True, with_pruner=True, cv_splitter= TimeSeriesSplit(16), warm_params=None)

    best_params = o_helper.study_best_params
    best_categories =  o_helper.study_best_params['categorical_features']
    best_features_count = len(x_tr.columns)

    score_train, score_val, _ = o_helper.run_model_and_eval(params=best_params,  categorical_features=best_categories, best_features_only=True, set_as_best_model=True)

    feat_imp_df = feat_imp_ext.plot_feature_importance(o_helper.best_model, o_helper.best_features_list, num=30, plot_bar=True)
    return o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df


def run_model_by_feature_count(o_helper, best_params, best_categories, best_features_count):
    o_helper.study_best_params = best_params
    o_helper.set_best_features_by_count(best_features_count)
    score_tr, score_vl, _ = o_helper.run_model_and_eval(params=best_params,  categorical_features=best_categories, best_features_only=True, set_as_best_model=True)
    return score_tr, score_vl


def save_score_and_params(target, pol_id, use_weather_cols, use_aqi_cols, use_c_mean_cols, use_lag_cols, use_gen_lags_cols,
                          best_params, best_categories, best_features_count, score_train, score_val):
    df_score.loc[df_score.shape[0]] = {'target': target, 'pol_id' : pol_id, 'weather_YN': use_weather_cols, 'AQI_lags_YN': use_aqi_cols,
                                       'C_lags_YN': use_c_mean_cols, 'simple_lags_YN': use_lag_cols, 'gen_lags_YN': use_gen_lags_cols,
                                       'params': best_params, 'categories': best_categories, 'top_feat_count': best_features_count,
                                       'train_score': score_train, 'val_score': score_val }
    df_score.to_csv(CSV_SCORE_FILE)

# %% [markdown]
# # Test models

# %% [markdown]
# ## PM 2.5

# %% [markdown]
# ### PM2.5 - AQI weather, lags, gen lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = True
use_gen_lags_cols =True
use_weather_cols = True

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# [I 2023-03-01 17:25:15,826] A new study created in memory with name: _
# run_params_search n_trials=10, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/10 [00:00<?, ?it/s]
# Trial 1 finished with best value: 36.43004321477383 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2400, 'num_leaves': 39, 'learning_rate': 0.13955479448311064, 'subsample': 0.47405375976335906, 'subsample_freq': 4, 'subsample_for_bin': 461365, 'min_child_samples': 473, 'reg_alpha': 0.8466914317107669, 'reg_lambda': 0.29512592129660564, 'max_depth': 5, 'max_bin': 396, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 3 finished with best value: 31.901224075324365 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 63, 'learning_rate': 0.05546308942113839, 'subsample': 0.2846278865963082, 'subsample_freq': 3, 'subsample_for_bin': 180145, 'min_child_samples': 230, 'reg_alpha': 0.26551419148094246, 'reg_lambda': 0.8704299229637551, 'max_depth': 12, 'max_bin': 170, 'categorical_features': ['season', 'month']}.
# Trial 4 finished with best value: 28.433678217666554 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2300, 'num_leaves': 58, 'learning_rate': 0.07387220238010136, 'subsample': 0.88180503972761, 'subsample_freq': 10, 'subsample_for_bin': 310533, 'min_child_samples': 504, 'reg_alpha': 0.029592095833324672, 'reg_lambda': 0.7304659290337103, 'max_depth': 6, 'max_bin': 385, 'categorical_features': ['season', 'month']}.
# Trial 5 finished with best value: 27.19510489932436 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1100, 'num_leaves': 25, 'learning_rate': 0.12131185781261511, 'subsample': 0.33105166206309034, 'subsample_freq': 0, 'subsample_for_bin': 173813, 'min_child_samples': 456, 'reg_alpha': 0.9633643162549045, 'reg_lambda': 0.8195399263992954, 'max_depth': 7, 'max_bin': 270, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 6 finished with best value: 24.008244750833477 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2500, 'num_leaves': 71, 'learning_rate': 0.05255099097803742, 'subsample': 0.6131566037331485, 'subsample_freq': 4, 'subsample_for_bin': 399116, 'min_child_samples': 224, 'reg_alpha': 0.2350729286778448, 'reg_lambda': 0.43770830242136616, 'max_depth': 11, 'max_bin': 117, 'categorical_features': ['month', 'weekday']}.
# Trial 2 finished with best value: 21.548193161762175 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1600, 'num_leaves': 112, 'learning_rate': 0.05893188047502328, 'subsample': 0.7691167111588387, 'subsample_freq': 5, 'subsample_for_bin': 143831, 'min_child_samples': 207, 'reg_alpha': 0.5021490937399713, 'reg_lambda': 0.7449193402616079, 'max_depth': 9, 'max_bin': 214, 'categorical_features': ['season', 'month']}.
# Trial 0 finished with best value: 19.491752703451382 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1000, 'num_leaves': 133, 'learning_rate': 0.07389652488876164, 'subsample': 0.982410158300637, 'subsample_freq': 5, 'subsample_for_bin': 248522, 'min_child_samples': 97, 'reg_alpha': 0.9897528849033357, 'reg_lambda': 0.6040347527222288, 'max_depth': 12, 'max_bin': 170, 'categorical_features': ['month', 'weekday']}.
# (8.311761500503348, 44.871087766894206)

# %%
best_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 97, 'learning_rate': 0.11890042003021366, 'subsample': 0.4318782580934736, 'subsample_freq': 0, 'subsample_for_bin': 193295, 'min_child_samples': 14, 'reg_alpha': 0.394194026403052, 'reg_lambda': 0.708405421324422, 'max_depth': 3, 'max_bin': 206}

score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
best_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 97, 'learning_rate': 0.11890042003021366, 'subsample': 0.4318782580934736, 'subsample_freq': 0, 'subsample_for_bin': 193295, 'min_child_samples': 14, 'reg_alpha': 0.394194026403052, 'reg_lambda': 0.708405421324422, 'max_depth': 3, 'max_bin': 206}
best_categories = ['month', 'weekday']
best_features_count = 70

o_helper, _, _, _, _ = init_optuna_helper(df_joint, pol_id, default_category=best_categories, categories=[],
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols,
                                          use_weather_cols=use_weather_cols)

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (4.741127620346672, 37.0975794319391)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# ### PM2.5 - AQI lags, gen lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = True
use_gen_lags_cols =True
use_weather_cols = False

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# run_params_search n_trials=100, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Trial 2 finished with best value: 30.0284626851883 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1900, 'num_leaves': 72, 'learning_rate': 0.09912091766563294, 'subsample': 0.09280121443065237, 'subsample_freq': 0, 'subsample_for_bin': 122763, 'min_child_samples': 552, 'reg_alpha': 0.24782428240975052, 'reg_lambda': 0.2871058524594158, 'max_depth': 5, 'max_bin': 83, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 5 finished with best value: 29.992788198365346 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2800, 'num_leaves': 90, 'learning_rate': 0.0787227499536775, 'subsample': 0.9196100698224192, 'subsample_freq': 5, 'subsample_for_bin': 230779, 'min_child_samples': 502, 'reg_alpha': 0.7029881164384739, 'reg_lambda': 0.9103496714991111, 'max_depth': 5, 'max_bin': 334, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 4 finished with best value: 27.01856181397476 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 3000, 'num_leaves': 88, 'learning_rate': 0.08124582800381384, 'subsample': 0.9998720099057018, 'subsample_freq': 5, 'subsample_for_bin': 368862, 'min_child_samples': 431, 'reg_alpha': 0.49560831642922054, 'reg_lambda': 0.08896247553616643, 'max_depth': 8, 'max_bin': 67, 'categorical_features': ['month', 'weekday']}.
# Trial 1 finished with best value: 26.289632934401766 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1100, 'num_leaves': 67, 'learning_rate': 0.14854257155221096, 'subsample': 0.7958100013943279, 'subsample_freq': 4, 'subsample_for_bin': 480299, 'min_child_samples': 239, 'reg_alpha': 0.4439049570666149, 'reg_lambda': 0.0708298431904395, 'max_depth': 12, 'max_bin': 348, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 8 finished with best value: 26.266933057884053 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2200, 'num_leaves': 100, 'learning_rate': 0.0665049235685286, 'subsample': 0.8887667587696637, 'subsample_freq': 3, 'subsample_for_bin': 483746, 'min_child_samples': 274, 'reg_alpha': 0.7734358459008615, 'reg_lambda': 0.9763664392506151, 'max_depth': 11, 'max_bin': 264, 'categorical_features': ['season', 'month']}.
# Trial 15 finished with best value: 24.427799133087106 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1400, 'num_leaves': 24, 'learning_rate': 0.15845089722322053, 'subsample': 0.837036321355315, 'subsample_freq': 2, 'subsample_for_bin': 496740, 'min_child_samples': 174, 'reg_alpha': 0.943923693804558, 'reg_lambda': 0.39957315305704744, 'max_depth': 12, 'max_bin': 398, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 18 finished with best value: 24.37131542920094 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2400, 'num_leaves': 40, 'learning_rate': 0.11596592005318514, 'subsample': 0.9969049113852211, 'subsample_freq': 2, 'subsample_for_bin': 434534, 'min_child_samples': 216, 'reg_alpha': 0.6033860163112652, 'reg_lambda': 0.07649849549813115, 'max_depth': 12, 'max_bin': 391, 'categorical_features': ['month', 'weekday']}.
# Trial 16 finished with best value: 22.81155703495051 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2300, 'num_leaves': 30, 'learning_rate': 0.1211756385809574, 'subsample': 0.9991862354416134, 'subsample_freq': 2, 'subsample_for_bin': 449471, 'min_child_samples': 162, 'reg_alpha': 0.8994331993751933, 'reg_lambda': 0.09632836669293304, 'max_depth': 12, 'max_bin': 400, 'categorical_features': ['month', 'weekday']}.
# Trial 23 finished with best value: 22.670468399828444 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1500, 'num_leaves': 20, 'learning_rate': 0.1163433343337856, 'subsample': 0.9946655447073801, 'subsample_freq': 2, 'subsample_for_bin': 356785, 'min_child_samples': 146, 'reg_alpha': 0.9564202064412175, 'reg_lambda': 0.20315417406882716, 'max_depth': 3, 'max_bin': 389, 'categorical_features': ['month', 'weekday']}.
# Trial 27 finished with best value: 20.847152284971905 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2500, 'num_leaves': 41, 'learning_rate': 0.10898189220104985, 'subsample': 0.9939014616637941, 'subsample_freq': 0, 'subsample_for_bin': 357346, 'min_child_samples': 78, 'reg_alpha': 0.9767388189661372, 'reg_lambda': 0.17814033766749032, 'max_depth': 3, 'max_bin': 360, 'categorical_features': ['month', 'weekday']}.
# Trial 28 finished with best value: 20.803027815819043 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2600, 'num_leaves': 41, 'learning_rate': 0.1322216579142535, 'subsample': 0.45346747882312916, 'subsample_freq': 0, 'subsample_for_bin': 338735, 'min_child_samples': 47, 'reg_alpha': 0.8633621062896906, 'reg_lambda': 0.19413837580176357, 'max_depth': 3, 'max_bin': 299, 'categorical_features': ['month', 'weekday']}.
# Trial 29 finished with best value: 20.753732342517534 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2600, 'num_leaves': 42, 'learning_rate': 0.13153772148996704, 'subsample': 0.7478738626512539, 'subsample_freq': 0, 'subsample_for_bin': 332940, 'min_child_samples': 47, 'reg_alpha': 0.8528722755264806, 'reg_lambda': 0.20575480862723047, 'max_depth': 3, 'max_bin': 303, 'categorical_features': ['month', 'weekday']}.
# Trial 30 finished with best value: 20.737156150139953 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2600, 'num_leaves': 38, 'learning_rate': 0.10247859289629578, 'subsample': 0.7268680673737428, 'subsample_freq': 0, 'subsample_for_bin': 315756, 'min_child_samples': 15, 'reg_alpha': 0.8511681111740053, 'reg_lambda': 0.20088120810581828, 'max_depth': 3, 'max_bin': 291, 'categorical_features': ['month', 'weekday']}.
# Trial 42 finished with best value: 20.724255361150966 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 3000, 'num_leaves': 52, 'learning_rate': 0.139852105552117, 'subsample': 0.7498664191320114, 'subsample_freq': 7, 'subsample_for_bin': 264055, 'min_child_samples': 57, 'reg_alpha': 0.777387407916196, 'reg_lambda': 0.4731941196845567, 'max_depth': 4, 'max_bin': 216, 'categorical_features': ['month', 'weekday']}.
# Trial 51 finished with best value: 20.687396631676396 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2900, 'num_leaves': 66, 'learning_rate': 0.12773019092749138, 'subsample': 0.7831659496800467, 'subsample_freq': 8, 'subsample_for_bin': 391616, 'min_child_samples': 73, 'reg_alpha': 0.6968311953663399, 'reg_lambda': 0.32426383763516786, 'max_depth': 5, 'max_bin': 329, 'categorical_features': ['month', 'weekday']}.
# (9.171279966153719, 64.22873357788919)

# %%
best_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2900, 'num_leaves': 66, 'learning_rate': 0.12773019092749138, 'subsample': 0.7831659496800467, 'subsample_freq': 8, 'subsample_for_bin': 391616, 'min_child_samples': 73, 'reg_alpha': 0.6968311953663399, 'reg_lambda': 0.32426383763516786, 'max_depth': 5, 'max_bin': 329}
best_categories = ['month', 'weekday']
best_features_count = 70

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (11.56874910200041, 66.33392921297678)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# ### PM2.5 - AQI weather, lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = True
use_gen_lags_cols =False
use_weather_cols = True

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# run_params_search n_trials=100, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Trial 4 finished with best value: 47.65738808816404 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1700, 'num_leaves': 84, 'learning_rate': 0.09355263273755747, 'subsample': 0.202164769665658, 'subsample_freq': 4, 'subsample_for_bin': 289043, 'min_child_samples': 427, 'reg_alpha': 0.5637945894541702, 'reg_lambda': 0.8363693940814599, 'max_depth': 9, 'max_bin': 243, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 3 finished with best value: 30.444463337798997 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1800, 'num_leaves': 123, 'learning_rate': 0.14944281331311549, 'subsample': 0.23931302846371838, 'subsample_freq': 8, 'subsample_for_bin': 168783, 'min_child_samples': 172, 'reg_alpha': 0.8938962304815726, 'reg_lambda': 0.2636477251306174, 'max_depth': 7, 'max_bin': 150, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 5 finished with best value: 21.2598306309417 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2700, 'num_leaves': 57, 'learning_rate': 0.15199553300759094, 'subsample': 0.6518857221046129, 'subsample_freq': 7, 'subsample_for_bin': 475906, 'min_child_samples': 152, 'reg_alpha': 0.2604360369862718, 'reg_lambda': 0.20224207424503038, 'max_depth': 6, 'max_bin': 149, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 2 finished with best value: 17.10895457005828 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2500, 'num_leaves': 89, 'learning_rate': 0.13217765351893046, 'subsample': 0.7226237839937268, 'subsample_freq': 10, 'subsample_for_bin': 94891, 'min_child_samples': 68, 'reg_alpha': 0.9486286909080761, 'reg_lambda': 0.706283740463815, 'max_depth': 7, 'max_bin': 83, 'categorical_features': ['season', 'month']}.
# Trial 15 finished with best value: 17.014480345092217 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1000, 'num_leaves': 64, 'learning_rate': 0.124360991159044, 'subsample': 0.992682224144549, 'subsample_freq': 10, 'subsample_for_bin': 55599, 'min_child_samples': 42, 'reg_alpha': 0.6200581907408236, 'reg_lambda': 0.6475981578119401, 'max_depth': 3, 'max_bin': 317, 'categorical_features': ['season', 'month']}.
# Trial 21 finished with best value: 16.92834210124252 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1000, 'num_leaves': 66, 'learning_rate': 0.12371937331367026, 'subsample': 0.9968668806201014, 'subsample_freq': 10, 'subsample_for_bin': 153869, 'min_child_samples': 35, 'reg_alpha': 0.7453915560894397, 'reg_lambda': 0.6942459220067211, 'max_depth': 3, 'max_bin': 314, 'categorical_features': ['season', 'month']}.
# Trial 34 finished with best value: 16.896949524999197 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1200, 'num_leaves': 97, 'learning_rate': 0.14332679318650826, 'subsample': 0.8133184969424178, 'subsample_freq': 0, 'subsample_for_bin': 396429, 'min_child_samples': 84, 'reg_alpha': 0.568790198444195, 'reg_lambda': 0.7598450245467973, 'max_depth': 9, 'max_bin': 204, 'categorical_features': ['season', 'month']}.
# Trial 37 finished with best value: 16.878630435925334 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1200, 'num_leaves': 69, 'learning_rate': 0.1135383428941053, 'subsample': 0.5571501010680322, 'subsample_freq': 0, 'subsample_for_bin': 202553, 'min_child_samples': 75, 'reg_alpha': 0.8606992856670004, 'reg_lambda': 0.6154821423806913, 'max_depth': 10, 'max_bin': 192, 'categorical_features': ['season', 'month']}.
# Trial 66 finished with best value: 16.847842345489617 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2500, 'num_leaves': 75, 'learning_rate': 0.11773005716354744, 'subsample': 0.8492590496632528, 'subsample_freq': 5, 'subsample_for_bin': 445398, 'min_child_samples': 34, 'reg_alpha': 0.7346043737792818, 'reg_lambda': 0.5541981697585945, 'max_depth': 3, 'max_bin': 224, 'categorical_features': ['season', 'month']}.
# Trial 82 finished with best value: 16.778126586669977 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1200, 'num_leaves': 64, 'learning_rate': 0.10270490839428205, 'subsample': 0.9664695832665771, 'subsample_freq': 1, 'subsample_for_bin': 487407, 'min_child_samples': 56, 'reg_alpha': 0.6541986070523397, 'reg_lambda': 0.4880242264611513, 'max_depth': 8, 'max_bin': 342, 'categorical_features': ['season', 'month']}.
# (10.197384104641882, 48.318526711830934)

# %%
#score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
best_categories = ['month', 'weekday']
best_features_count = 70

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (8.55951491370446, 46.97933900468251)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# ### PM2.5 - AQI weather, gen lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = False
use_gen_lags_cols =True
use_weather_cols = True

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# run_params_search n_trials=100, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Trial 2 finished with best value: 24.187729161588074 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1400, 'num_leaves': 119, 'learning_rate': 0.14699113957716364, 'subsample': 0.7063660655618115, 'subsample_freq': 1, 'subsample_for_bin': 319426, 'min_child_samples': 251, 'reg_alpha': 0.9114353405621362, 'reg_lambda': 0.2953735633668422, 'max_depth': 3, 'max_bin': 245, 'categorical_features': ['month', 'weekday']}.
# Trial 0 finished with best value: 19.850544958578567 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1900, 'num_leaves': 69, 'learning_rate': 0.14021310010804855, 'subsample': 0.657072708958782, 'subsample_freq': 4, 'subsample_for_bin': 453823, 'min_child_samples': 104, 'reg_alpha': 0.6735455441652652, 'reg_lambda': 0.20857661798419613, 'max_depth': 12, 'max_bin': 370, 'categorical_features': ['month', 'weekday']}.
# Trial 5 finished with best value: 17.577502992995182 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1300, 'num_leaves': 63, 'learning_rate': 0.05072717300855794, 'subsample': 0.7870175827017725, 'subsample_freq': 8, 'subsample_for_bin': 172417, 'min_child_samples': 51, 'reg_alpha': 0.7816718695260145, 'reg_lambda': 0.8730730703764521, 'max_depth': 7, 'max_bin': 399, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 16 finished with best value: 17.545810889317814 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2900, 'num_leaves': 20, 'learning_rate': 0.09145451415972891, 'subsample': 0.850416693655752, 'subsample_freq': 6, 'subsample_for_bin': 402129, 'min_child_samples': 29, 'reg_alpha': 0.5221684555879686, 'reg_lambda': 0.4942637266057903, 'max_depth': 9, 'max_bin': 305, 'categorical_features': ['month', 'weekday']}.
# Trial 41 finished with best value: 17.54313598746475 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2600, 'num_leaves': 34, 'learning_rate': 0.07694246459019187, 'subsample': 0.9211642276350414, 'subsample_freq': 6, 'subsample_for_bin': 449260, 'min_child_samples': 72, 'reg_alpha': 0.5685138243026013, 'reg_lambda': 0.3694293937971201, 'max_depth': 12, 'max_bin': 256, 'categorical_features': ['month', 'weekday']}.
# Trial 57 finished with best value: 17.497090892212857 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 3000, 'num_leaves': 27, 'learning_rate': 0.09393415562124541, 'subsample': 0.9382118607873008, 'subsample_freq': 5, 'subsample_for_bin': 492013, 'min_child_samples': 71, 'reg_alpha': 0.8548537958638365, 'reg_lambda': 0.33593121295261225, 'max_depth': 4, 'max_bin': 248, 'categorical_features': ['month', 'weekday']}.
# Trial 64 finished with best value: 17.447626158414643 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2700, 'num_leaves': 73, 'learning_rate': 0.08420931764396851, 'subsample': 0.8850253530522536, 'subsample_freq': 7, 'subsample_for_bin': 428637, 'min_child_samples': 33, 'reg_alpha': 0.7895516991287604, 'reg_lambda': 0.4290744169146675, 'max_depth': 4, 'max_bin': 167, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 67 finished with best value: 17.443259517639472 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2900, 'num_leaves': 25, 'learning_rate': 0.09802486000485351, 'subsample': 0.8797540789258037, 'subsample_freq': 7, 'subsample_for_bin': 490429, 'min_child_samples': 38, 'reg_alpha': 0.40339650810451805, 'reg_lambda': 0.30482144734455624, 'max_depth': 4, 'max_bin': 258, 'categorical_features': ['month', 'weekday']}.
# Trial 71 finished with best value: 17.349094426145005 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2700, 'num_leaves': 57, 'learning_rate': 0.09270957354053376, 'subsample': 0.8709112845821021, 'subsample_freq': 6, 'subsample_for_bin': 433912, 'min_child_samples': 33, 'reg_alpha': 0.3411669098269467, 'reg_lambda': 0.1373366285943397, 'max_depth': 4, 'max_bin': 141, 'categorical_features': ['month', 'weekday']}.
# (10.19695169114189, 46.33802571421732)

# %%
# best_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1600, 'num_leaves': 145, 'learning_rate': 0.09686633344736045, 'subsample': 0.9783886230574863, 'subsample_freq': 3, 'subsample_for_bin': 210165, 'min_child_samples': 36, 'reg_alpha': 0.6996611491876404, 'reg_lambda': 0.6668213755991776, 'max_depth': 5, 'max_bin': 339}

score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
best_categories = ['season', 'month']
best_features_count = 73

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (4.502194741012753, 39.73344399253436)

# %%
best_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 97, 'learning_rate': 0.11890042003021366, 'subsample': 0.4318782580934736, 'subsample_freq': 0, 'subsample_for_bin': 193295, 'min_child_samples': 14, 'reg_alpha': 0.394194026403052, 'reg_lambda': 0.708405421324422, 'max_depth': 3, 'max_bin': 206}
best_categories = ['month', 'weekday']
best_features_count = 73

o_helper, _, _, _, _ = init_optuna_helper(df_joint, pol_id, default_category=best_categories, categories=[],
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols,
                                          use_weather_cols=use_weather_cols)

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (4.096338645025627, 33.11449808343723)

# %%
score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# ### PM2.5 - AQI gen lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = False
use_gen_lags_cols =True
use_weather_cols = False

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# run_params_search n_trials=100, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Trial 2 finished with best value: 43.24161356139567 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 1700, 'num_leaves': 22, 'learning_rate': 0.10593410179641563, 'subsample': 0.35197482426511373, 'subsample_freq': 9, 'subsample_for_bin': 182517, 'min_child_samples': 467, 'reg_alpha': 0.09676308902565711, 'reg_lambda': 0.982528872986122, 'max_depth': 9, 'max_bin': 125, 'categorical_features': ['season', 'month']}.
# Trial 3 finished with best value: 33.15131085982554 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2400, 'num_leaves': 137, 'learning_rate': 0.09810190444767644, 'subsample': 0.6317452736130315, 'subsample_freq': 8, 'subsample_for_bin': 365019, 'min_child_samples': 508, 'reg_alpha': 0.349379305365927, 'reg_lambda': 0.12388551465051567, 'max_depth': 3, 'max_bin': 316, 'categorical_features': ['season', 'month']}.
# Trial 7 finished with best value: 29.957903251408727 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1900, 'num_leaves': 85, 'learning_rate': 0.12320675484842857, 'subsample': 0.8506947198114617, 'subsample_freq': 9, 'subsample_for_bin': 320637, 'min_child_samples': 509, 'reg_alpha': 0.939862825932252, 'reg_lambda': 0.26540279962718505, 'max_depth': 10, 'max_bin': 182, 'categorical_features': ['month', 'weekday']}.
# Trial 5 finished with best value: 23.963223301667426 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2800, 'num_leaves': 58, 'learning_rate': 0.12132427305443214, 'subsample': 0.1115750935246741, 'subsample_freq': 3, 'subsample_for_bin': 267415, 'min_child_samples': 26, 'reg_alpha': 0.862769047538464, 'reg_lambda': 0.5870520764615527, 'max_depth': 7, 'max_bin': 267, 'categorical_features': ['month', 'weekday']}.
# Trial 4 finished with best value: 22.820026201893373 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2700, 'num_leaves': 23, 'learning_rate': 0.15013109218386048, 'subsample': 0.9452340676704938, 'subsample_freq': 1, 'subsample_for_bin': 396768, 'min_child_samples': 151, 'reg_alpha': 0.7878527287720382, 'reg_lambda': 0.27690456669181795, 'max_depth': 6, 'max_bin': 159, 'categorical_features': ['season', 'month']}.
# Trial 6 finished with best value: 20.877024944579794 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1700, 'num_leaves': 99, 'learning_rate': 0.13844796202296958, 'subsample': 0.3952276892740745, 'subsample_freq': 0, 'subsample_for_bin': 114858, 'min_child_samples': 45, 'reg_alpha': 0.616578830102622, 'reg_lambda': 0.1785781026134864, 'max_depth': 5, 'max_bin': 351, 'categorical_features': ['month', 'weekday']}.
# Trial 22 finished with best value: 20.845068972921414 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1300, 'num_leaves': 103, 'learning_rate': 0.14186521435319077, 'subsample': 0.866300158106328, 'subsample_freq': 0, 'subsample_for_bin': 373531, 'min_child_samples': 86, 'reg_alpha': 0.545234695602149, 'reg_lambda': 0.18898826679866138, 'max_depth': 7, 'max_bin': 132, 'categorical_features': ['season', 'month']}.
# Trial 60 finished with best value: 20.821251133896645 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1100, 'num_leaves': 54, 'learning_rate': 0.14360821753512984, 'subsample': 0.8843248090682493, 'subsample_freq': 10, 'subsample_for_bin': 351150, 'min_child_samples': 76, 'reg_alpha': 0.3583329028931461, 'reg_lambda': 0.21514414988010017, 'max_depth': 7, 'max_bin': 254, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 61 finished with best value: 20.77725548860269 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1100, 'num_leaves': 54, 'learning_rate': 0.14370536256861705, 'subsample': 0.9672585942249439, 'subsample_freq': 10, 'subsample_for_bin': 348943, 'min_child_samples': 70, 'reg_alpha': 0.34793890385128207, 'reg_lambda': 0.12964471171167424, 'max_depth': 10, 'max_bin': 255, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 97 finished with best value: 20.772177766380096 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1000, 'num_leaves': 37, 'learning_rate': 0.13860410322879588, 'subsample': 0.863895140050221, 'subsample_freq': 8, 'subsample_for_bin': 239843, 'min_child_samples': 54, 'reg_alpha': 0.42273520609087656, 'reg_lambda': 0.18039140663406658, 'max_depth': 9, 'max_bin': 238, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 98 finished with best value: 20.738329550073964 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1200, 'num_leaves': 145, 'learning_rate': 0.15946462060002448, 'subsample': 0.8195844377256735, 'subsample_freq': 9, 'subsample_for_bin': 268194, 'min_child_samples': 51, 'reg_alpha': 0.4480255728796678, 'reg_lambda': 0.16685486531146257, 'max_depth': 9, 'max_bin': 290, 'categorical_features': ['season', 'month', 'weekday']}.
# (3.146477648548509, 56.73801106956682)

# %%
#score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
best_categories = ['month', 'weekday']
best_features_count = 70

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (6.1046403179356545, 56.35866633346242)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# ### PM2.5 - AQI lags

# %%
pol_id = 6001
categories=[['month', 'weekday'], ['season', 'month'], ['season', 'month', 'weekday']]
default_category=['month', 'weekday']
use_aqi_cols = False
use_c_mean_cols=True
use_lag_cols = True
use_gen_lags_cols = False
use_weather_cols = False

# %%
o_helper, score_train, score_val, best_params, best_categories, best_features_count, feat_imp_df = \
    run_test(df_joint, pol_id, default_category=default_category, categories=categories,
             use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols, use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols)
score_train, score_val
# Out:
# run_params_search n_trials=100, search_category=True, best_features_only=True, with_pruner=True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Trial 5 finished with best value: 47.65738808816404 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 123, 'learning_rate': 0.11690586150765034, 'subsample': 0.05833966549122971, 'subsample_freq': 3, 'subsample_for_bin': 156130, 'min_child_samples': 380, 'reg_alpha': 0.7661800043956998, 'reg_lambda': 0.8184762004474069, 'max_depth': 7, 'max_bin': 139, 'categorical_features': ['season', 'month']}.
# Trial 1 finished with best value: 35.418889869994594 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1400, 'num_leaves': 24, 'learning_rate': 0.09008607406287047, 'subsample': 0.6007046931682812, 'subsample_freq': 7, 'subsample_for_bin': 395236, 'min_child_samples': 504, 'reg_alpha': 0.8543201899894292, 'reg_lambda': 0.40292266234288965, 'max_depth': 5, 'max_bin': 206, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 6 finished with best value: 29.956239838802617 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1800, 'num_leaves': 94, 'learning_rate': 0.09872719657277104, 'subsample': 0.10216837179440386, 'subsample_freq': 0, 'subsample_for_bin': 103099, 'min_child_samples': 573, 'reg_alpha': 0.20415646183661706, 'reg_lambda': 0.6681610793600564, 'max_depth': 12, 'max_bin': 198, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 7 finished with best value: 29.120724052097653 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2400, 'num_leaves': 34, 'learning_rate': 0.14016269602005468, 'subsample': 0.4921872713046467, 'subsample_freq': 4, 'subsample_for_bin': 54063, 'min_child_samples': 236, 'reg_alpha': 0.2669676804074519, 'reg_lambda': 0.44045677718327914, 'max_depth': 6, 'max_bin': 381, 'categorical_features': ['month', 'weekday']}.
# Trial 8 finished with best value: 22.690602605666243 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2600, 'num_leaves': 50, 'learning_rate': 0.1121743822736416, 'subsample': 0.8958339682369933, 'subsample_freq': 2, 'subsample_for_bin': 255171, 'min_child_samples': 149, 'reg_alpha': 0.3775414807420616, 'reg_lambda': 0.3739058557816518, 'max_depth': 9, 'max_bin': 203, 'categorical_features': ['season', 'month', 'weekday']}.
# Trial 13 finished with best value: 20.797583667081575 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2700, 'num_leaves': 51, 'learning_rate': 0.12331688149148431, 'subsample': 0.5987034969269206, 'subsample_freq': 1, 'subsample_for_bin': 337998, 'min_child_samples': 16, 'reg_alpha': 0.33644777472865395, 'reg_lambda': 0.9874900399765433, 'max_depth': 3, 'max_bin': 119, 'categorical_features': ['month', 'weekday']}.
# Trial 10 finished with best value: 20.692471908388985 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 1600, 'num_leaves': 39, 'learning_rate': 0.11471279256907006, 'subsample': 0.8683299501038435, 'subsample_freq': 9, 'subsample_for_bin': 342526, 'min_child_samples': 58, 'reg_alpha': 0.052319149688483946, 'reg_lambda': 0.015481937017789327, 'max_depth': 9, 'max_bin': 310, 'categorical_features': ['month', 'weekday']}.
# Trial 20 finished with best value: 20.633803393596896 and parameters: {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': True, 'n_estimators': 2500, 'num_leaves': 77, 'learning_rate': 0.05414860183525777, 'subsample': 0.7235785644067575, 'subsample_freq': 0, 'subsample_for_bin': 325370, 'min_child_samples': 51, 'reg_alpha': 0.4232895603733003, 'reg_lambda': 0.987762345778946, 'max_depth': 9, 'max_bin': 58, 'categorical_features': ['season', 'month', 'weekday']}.
# (17.550596821552734, 79.37578102566341)

# %%
#score_and_plot_by_feature_count(o_helper, len_features=min(best_features_count, 150), best_params=best_params, categories=categories)

# %%
best_categories = ['season', 'month', 'weekday']
best_features_count = 70

score_train, score_val = run_model_by_feature_count(o_helper, best_params, best_categories=best_categories, best_features_count=best_features_count)
score_train, score_val
# Out:
# (17.517325411600407, 78.71140966591524)

# %%
save_score_and_params(target='AQI', pol_id=pol_id, use_weather_cols=use_weather_cols, use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
                      use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, best_params=best_params, best_categories=best_categories,
                      best_features_count=best_features_count, score_train=score_train, score_val=score_val)

# %% [markdown]
# # Forecasts comparison

# %%
df_score = pd.read_csv(CSV_SCORE_FILE)
df_score.sort_values(by='val_score', inplace=True)
display(df_score)
# Out:
#    Unnamed: 0  train_score  val_score target  pol_id  weather_YN  AQI_lags_YN  \
# 3           4     4.096339  33.114498    AQI    6001        True        False
# 1           2     4.741128  37.097579    AQI    6001        True        False
# 0           1     8.559515  46.979339    AQI    6001        True        False
# 4           5     6.104640  56.358666    AQI    6001       False        False
# 2           3    11.568749  66.333929    AQI    6001       False        False
# 5           6    17.517325  78.711410    AQI    6001       False        False
#
#    C_lags_YN  simple_lags_YN  gen_lags_YN  \
# 3       True           False         True
# 1       True            True         True
# 0       True            True        False
# 4       True           False         True
# 2       True            True         True
# 5       True            True        False
#
#                                               params  \
# 3  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
# 1  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
# 0  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
# 4  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
# 2  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
# 5  {'n_jobs': -1, 'verbosity': -1, 'objective': '...
#
#                        categories  top_feat_count
# 3            ['month', 'weekday']              73
# 1            ['month', 'weekday']              70
# 0            ['month', 'weekday']              70
# 4            ['month', 'weekday']              70
# 2  ['season', 'month', 'weekday']              70
# 5  ['season', 'month', 'weekday']              70

# %%
_, y_val = ts_splitter.split_x_y_for_period(df=df_joint, index_cols='DatetimeEnd', y_value_col='AQI',                                                           dt_start=VAL_DATE_FROM, dt_end=VAL_DATE_TO)

# %%
def get_prediction(df, pol_id, use_weather_cols, use_aqi_cols, use_c_mean_cols, use_lag_cols, use_gen_lags_cols, best_params, best_categories, best_feat_count):
    o_helper, _, _, x_vl, _ = lgbm_fl.init_optuna(
        df=df, pol_id=pol_id, prediction_value_type=lgbm_fl.PredictionValueType.AQI,
        use_aqi_cols=use_aqi_cols, use_c_mean_cols=use_c_mean_cols,
        use_lag_cols=use_lag_cols, use_gen_lags_cols=use_gen_lags_cols, use_weather_cols=use_weather_cols,
        train_start_dt=TRAIN_DATE_FROM, train_end_dt=TRAIN_DATE_TO, test_start_dt=VAL_DATE_FROM, test_end_dt=VAL_DATE_TO,
        default_params=best_params, default_category=best_categories, default_top_features_count=best_feat_count)

    score_train, score_val, _ = o_helper.run_model_and_eval(best_features_only=True, set_as_best_model=True)
    y_vl_pred = [int(round(x, 0)) for x in o_helper.predict_by_best_model(x_vl)]
    return score_train, score_val, y_vl_pred

# %%
plt.figure(figsize=(15, 4))
plt.title(f"Прогноз AQI на последние 7 дней")
plt.plot(y_val, label="actual")

for index, row in df_score.iterrows():
    str_type = ''
    if row['weather_YN']:
            str_type = 'Weather'
    if row['simple_lags_YN']:
        if str_type != '':
            str_type = str_type + '_'
        str_type = str_type + 'SimpleLags'
    if row['gen_lags_YN']:
        if str_type != '':
            str_type = str_type + '_'
        str_type = str_type + 'GenLags'

    best_pm25_params = {'n_jobs': -1, 'verbosity': -1, 'objective': 'regression', 'metric': 'rmse', 'boosting_type': 'gbdt', 'extra_trees': False, 'n_estimators': 2100, 'num_leaves': 97, 'learning_rate': 0.11890042003021366, 'subsample': 0.4318782580934736, 'subsample_freq': 0, 'subsample_for_bin': 193295, 'min_child_samples': 14, 'reg_alpha': 0.394194026403052, 'reg_lambda': 0.708405421324422, 'max_depth': 3, 'max_bin': 206}
    best_pm25_categories = ['month', 'weekday']
    best_pm25_features_count = 70

    score_train, score_val, y_pred = get_prediction(df_joint, row['pol_id'], row['weather_YN'], row['AQI_lags_YN'], row['C_lags_YN'], row['simple_lags_YN'], row['gen_lags_YN'], eval(row['params']), eval(row['categories']), row['top_feat_count'])
    print(f'{str_type}: train score: {score_train}, val score: {score_val}')
    plt.plot(y_val.index, y_pred, label=str_type + ". RMSE=%.2f" % score_val)


plt.legend()
plt.grid(True)
plt.show()
# Out:
# Weather_GenLags: train score: 4.096338645025626, val score: 33.11449808343723
# Weather_SimpleLags_GenLags: train score: 4.741127620346672, val score: 37.0975794319391
# Weather_SimpleLags: train score: 8.55951491370446, val score: 46.97933900468251
# GenLags: train score: 6.1046403179356545, val score: 56.358666333462416
# SimpleLags_GenLags: train score: 12.124822284695902, val score: 64.47869336470109
# SimpleLags: train score: 17.391011704100737, val score: 78.70410345887969
